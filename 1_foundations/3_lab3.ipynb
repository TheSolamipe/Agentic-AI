# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
# Oloyede  Solamipe  Akinola
# Technical
#
# Product
#
# Manager
#
# |
#
# Chief
#
# Product
#
# Officer
#
# 📍
#
# Lagos,
#
# Nigeria
#
# |
#
# 📞
#
# +234
#
# 810
#
# 225
#
# 9597
#
# |
#
# ✉
#
# akinolasolamipe@gmail.com
#  🔗  Portfolio:  https://bento.me/0xsolamipe |  LinkedIn
# Professional  Summary
# Experienced  and  forward-thinking  Technical  Product  Manager  and  Chief  Product  Officer  with
# over
#
# 6
#
# years
#
# of
#
# experience
#
# delivering
#
# high-impact
#
# products
#
# across
#
# fintech,
#
# social
#
# apps,
#
# luxury
#
# tech,
#
# e-commerce,
#
# blockchain,
#
# AI,
#
# and
#
# Web3
# .
#
# Proven
#
# expertise
#
# in
#
# product
#
# strategy,
#
# system
#
# design,
#
# and
#
# leading
#
# high-performing
#
# cross-functional
#
# teams.
#
# Adept
#
# at
#
# transforming
#
# insights
#
# into
#
# features
#
# that
#
# drive
#
# measurable
#
# growth.
#
# ●  Key  Achievement :  Led  the  design  and  implementation  of  a  new  feature  that  increased
# product
#
# usage
#
# by
#
# 72%
# ,
#
# leveraging
#
# behavioral
#
# data
#
# from
#
# 3,000+
#
# users
# .
#  ●  Technical  leader  who  combines  deep  domain  knowledge  with  strategic  execution,
# having
#
# managed
#
# multi-million-dollar
#
# product
#
# portfolios
#
# and
#
# scaled
#
# products
#
# used
#
# by
#
# 10,000+
#
# active
#
# users
# .
#
#
# Experience
# MOBI  Automation  –  Dubai  (Fulltime)
# Chief  Product  Officer  ·  May  2024  –  Present
# ●  Promoted  from  Technical  Product  Manager  to  Chief  Product  Officer  due  to  strong
# performance.
#  ●  Designed  and  led  development  of  AI  and  blockchain  platforms  with  10,000+  users .  ●  Directed  multiple  associate  product  managers  across  distinct  verticals  and  oversaw
# product
#
# roadmaps.
#  ●  Managed  portfolios  worth  $2M+ ,  driving  measurable  growth  in  ROI  and  user
# engagement.
#  ●  Contributed  to  investment  strategy  and  community  feedback  loops  to  improve
# satisfaction.
#
# Technical  Product  Manager  ·  Mar  2022  –  Apr  2024
# ●  Introduced  a  customer  feedback  loop  that  improved  user  satisfaction  by  20%  and
# decreased
#
# negative
#
# reviews.
#  ●  Built  and  launched  an  admin  dashboard  managing  activity  across  5  blockchain
# networks
# ,
#
# reducing
#
# churn
#
# by
#
# 91%
#
# in
#
# 6
#
# months.
#  ●  Delivered  strategic  direction  and  feature  development  across  6+  major  product  lines .  Product  Manager  ·  Oct  2021  –  Feb  2022
# ●  Managed  a  10+  person  team  that  launched  products  generating  $1M  in  revenue  within
# 4
#
# months.
#  ●  Launched  a  mobile-responsive  dApp,  increasing  engagement  by  50%  and  DAU  by  25% .  ●  Led  collaboration  among  24+  team  members  to  drive  35%  user  base  growth  and  67%
# increase
#
# in
#
# profitability
# .
#
#
# Luxor  –  Lagos  (Contract )
# AI  Product  Consultant  .  Feb  2024  –  May  2024
# ●  Designed  and  developed  an  AI-powered  luxury  authentication  system  utilizing  machine
# learning
#
# and
#
# computer
#
# vision,
#
# achieving
#
# a
#
# 92%
#
# accuracy
#
# rate
#
# in
#
# identifying
#
# counterfeit
#
# luxury
#
# items
#
# across
#
# beta
#
# test
#
# datasets.
#  ●  Collaborated  with  product,  design,  and  R&D  teams  to  align  AI  product  flows  with
# ultra-high-net-worth
#
# (UHNW)
#
# user
#
# expectations,
#
# contributing
#
# to
#
# a
#
# 38%
#
# increase
#
# in
#
# early
#
# adopter
#
# interest
#
# during
#
# pre-launch.
#  ●  Architected  and  deployed  an  LLM  benchmarking  system  to  enhance  intelligent  access
# control
#
# to
#
# user
#
# data,
#
# improving
#
# data
#
# query
#
# speed
#
# by
#
# 40%
#
# and
#
# lowering
#
# error
#
# rates
#
# by
#
# 22%
# .
#  ●  Applied  prompt  engineering  techniques  to  decentralized  LLM  environments,  resulting  in
# a
#
# 55%
#
# boost
#
# in
#
# retrieval
#
# precision
#
# during
#
# internal
#
# quality
#
# tests
#
# for
#
# high-context
#
# queries.
#
#
# DockHive  –  Remote  (Contract)
# Technical  Product  Manager  ·  Jul  2023  –  Dec  2023
# ●  Led  a  research  initiative  with  100+  users  to  uncover  key  pain  points  in  cloud
# infrastructure.
#  ●  Built  a  decentralized  cloud  service  platform  with  a  team  of  10+,  optimizing  backend
# performance.
#  ●  Reduced  post-launch  bugs  by  30%  through  rigorous  testing.  ●  Iterated  features  based  on  feedback,  improving  satisfaction  by  35%  and  cutting  support
# tickets
#
# by
#
# 20%
# .
#
#
#  CredPal  (YC  W19)  –  Lagos,  Nigeria
# Technical  Product  Manager  ·  Aug  2021  –  Oct  2021
# ●  Conducted  user  research  to  prioritize  10+  features,  resulting  in  77%  satisfaction
# improvement
# .
#  ●  Launched  a  “Fractional  Repayment”  feature,  reducing  defaults  by  34%  and  raising  app
# rating
#
# from
#
# 3.5
#
# to
#
# 4.2
# .
#  ●  Enhanced  KYC  flows,  reducing  outstanding  monthly  debt  by  56% .
#
# PaceSwap  –  Nigeria  (Contract)
# Technical  Product  Manager  ·  Jan  2021  –  Jun  2021
# ●  Surveyed  2,000  crypto  users ,  integrating  feedback  that  improved  satisfaction  by  45% .  ●  Reduced  development  cycle  time  by  30%  through  improved  workflows  among  15+  team
# members.
#  ●  Implemented  robust  multi-factor  security,  reducing  incidents  by  60% .  ●  Launched  iOS  &  Android  wallets  with  100,000+  downloads  in  the  first  month  and  25%
# MoM
#
# active
#
# user
#
# growth
# .
#
#
# OneWildcard  –  Lagos,  Nigeria
# Software  Developer  ·  Nov  2020  –  Oct  2021
# ●  Developed  and  deployed  a  fully  functional  eCommerce  platform  ( pizzajungleng.com )
# using
#
# Next.js
# ,
#
# GraphQL
# ,
#
# and
#
# WordPress
# ,
#
# resulting
#
# in
#
# a
#
# 120%
#
# increase
#
# in
#
# online
#
# orders
#
# within
#
# 3
#
# months
#
# post-launch.
#  ●  Optimized  frontend  performance  by  refactoring  query  logic  and  reducing  page  load  time
# by
#
# 47%
# ,
#
# improving
#
# overall
#
# user
#
# experience.
#  ●  Integrated  custom  payment  APIs  and  order  tracking  workflows,  leading  to  a  30%
# reduction
#
# in
#
# cart
#
# abandonment
#
# rates
# .
#  ●  Worked  closely  with  UI/UX  designers  to  implement  mobile-first  designs,  achieving  a
# 4.6-star
#
# average
#
# user
#
# rating
#
# across
#
# devices.
#
#
#  BlocMe  –  Ottawa,  Canada
# Product  Manager  ·  Apr  2019  –  Jan  2021
# ●  Led  extensive  product  discovery  efforts,  conducting  70+  customer  interviews  that
# informed
#
# the
#
# MVP
#
# and
#
# shaped
#
# end-to-end
#
# user
#
# journey
#
# flows.
#  ●  Delivered  the  MVP  within  3  months,  enabling  the  team  to  secure  $150K  in  early-stage
# funding
#
# and
#
# a
#
# beta
#
# waitlist
#
# of
#
# 1,200+
#
# users
# .
#  ●  Defined  and  prioritized  a  product  backlog  of  30+  features  using  user  feedback  and
# business
#
# goals,
#
# resulting
#
# in
#
# a
#
# 40%
#
# increase
#
# in
#
# user
#
# activation
#
# during
#
# pilot
#
# testing
# .
#  ●  Coordinated  bi-weekly  agile  sprints  with  a  cross-functional  team  of  8  engineers  and
# designers,
#
# maintaining
#
# an
#
# average
#
# on-time
#
# delivery
#
# rate
#
# of
#
# 92%
# .
#  ●  Implemented  an  early  analytics  loop  using  Mixpanel  to  track  onboarding  flow,  identifying
# a
#
# key
#
# drop-off
#
# and
#
# improving
#
# sign-up
#
# completion
#
# by
#
# 35%
# .
#
#
# AFREAL  –  Lagos,  Nigeria
# Frontend  Engineer  ·  Oct  2018  –  Dec  2020
# ●  Translated  Figma  designs  into  responsive,  pixel-perfect  UIs  using  React.js ,  improving
# design
#
# implementation
#
# speed
#
# by
#
# 40%
# .
#  ●  Implemented  Formik  and  Yup  for  advanced  form  validation,  reducing  user  input  errors
# by
#
# 65%
#
# across
#
# 3
#
# core
#
# features.
#  ●  Leveraged  Redux  for  scalable  state  management  across  multiple  frontend  modules,
# enhancing
#
# feature
#
# extensibility.
#  ●  Collaborated  with  backend  developers  to  integrate  10+  APIs,  reducing  frontend/backend
# integration
#
# issues
#
# by
#
# 50%
# during
#
# QA
#
# cycles.
#  ●  Contributed  to  UI  components  reused  across  3  projects,  increasing  dev  team  efficiency
# and
#
# maintaining
#
# visual
#
# consistency.
#
#
# Education
# University  of  Lagos  ·  B.Sc.,  Electrical  &  Electronics  Engineering  (2013–2018)
# Certifications
# ●  Certified  Blockchain  Expert  –  Blockchain  Council  ●  Certified  Metaverse  Expert  –  Blockchain  Council  ●  Becoming  a  Product  Manager  –  LinkedIn  Learning  Core  Skills
# ●  Product  &  Business :  Product  Management,  Market  Research,  Business  Strategy,  User
# Experience
#
# Design,
#
# Agile
#
# Leadership,
#
# Roadmapping
#  ●  Technical :  Blockchain  (Security,  Tokenomics),  Web3,  AI/ML  Product  Strategy,  Technical
# Architecture,
#
# Software
#
# Development
#  ●  Leadership :  Cross-functional  Team  Management,  Stakeholder  Engagement,
# Go-to-Market
#
# Execution
#
# Tools  &  Stack
# ●  PM  &  Dev  Tools :  Jira,  ClickUp,  Confluence,  GitHub,  Gitbook,  Postman,  VSCode,
# Chrome
#
# DevTools
#  ●  Design  Tools :  Figma  ●  Frontend :  HTML,  CSS,  Sass,  JavaScript,  React,  Next.js,  WordPress,  TailwindCSS,
# Material
#
# UI,
#
# Bootstrap
#  ●  Backend :  Node.js,  NestJS,  Python,  SQL,  MongoDB,  GraphQL  ●  Blockchain  &  Infra :  Solidity,  C++,  Web3.js,  Security  Auditing

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Oloyede Akinola"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Oloyede Akinola. You are answering questions on Oloyede Akinola's website, particularly questions related to Oloyede Akinola's career, background, skills and experience. Your responsibility is to represent Oloyede Akinola for interactions on the website as faithfully as possible. You are given a summary of Oloyede Akinola's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nTechnical product manager with 5+ years of experience developing software products, leading cross-functional teams, and analyzing metrics to drive product improvements. Key achievement: ideated and implemented a new product feature that boosted product usage by 72% using data analytics to identify the user behavior patterns of 3K+ customers.\n\n## LinkedIn Profile:\nOloyede  Solamipe  Akinola  \nTechnical\n \nProduct\n \nManager\n \n|\n \nChief\n \nProduct\n \nOfficer\n \n📍\n \nLagos,\n \nNigeria\n \n|\n \n📞\n \n+234\n \n810\n \n225\n \n9597\n \n|\n \n✉\n \nakinolasolamipe@gmail.com\n 🔗  Portfolio:  https://bento.me/0xsolamipe |  LinkedIn \nProfessional  Summary  \nExperienced  and  forward-thinking  Technical  Product  Manager  and  Chief  Product  Officer  with  \nover\n \n6\n \nyears\n \nof\n \nexperience\n \ndelivering\n \nhigh-impact\n \nproducts\n \nacross\n \nfintech,\n \nsocial\n \napps,\n \nluxury\n \ntech,\n \ne-commerce,\n \nblockchain,\n \nAI,\n \nand\n \nWeb3\n.\n \nProven\n \nexpertise\n \nin\n \nproduct\n \nstrategy,\n \nsystem\n \ndesign,\n \nand\n \nleading\n \nhigh-performing\n \ncross-functional\n \nteams.\n \nAdept\n \nat\n \ntransforming\n \ninsights\n \ninto\n \nfeatures\n \nthat\n \ndrive\n \nmeasurable\n \ngrowth.\n \n●  Key  Achievement :  Led  the  design  and  implementation  of  a  new  feature  that  increased  \nproduct\n \nusage\n \nby\n \n72%\n,\n \nleveraging\n \nbehavioral\n \ndata\n \nfrom\n \n3,000+\n \nusers\n.\n ●  Technical  leader  who  combines  deep  domain  knowledge  with  strategic  execution,  \nhaving\n \nmanaged\n \nmulti-million-dollar\n \nproduct\n \nportfolios\n \nand\n \nscaled\n \nproducts\n \nused\n \nby\n \n10,000+\n \nactive\n \nusers\n.\n \n \nExperience  \nMOBI  Automation  –  Dubai  (Fulltime)  \nChief  Product  Officer  ·  May  2024  –  Present  \n●  Promoted  from  Technical  Product  Manager  to  Chief  Product  Officer  due  to  strong  \nperformance.\n ●  Designed  and  led  development  of  AI  and  blockchain  platforms  with  10,000+  users .  ●  Directed  multiple  associate  product  managers  across  distinct  verticals  and  oversaw  \nproduct\n \nroadmaps.\n ●  Managed  portfolios  worth  $2M+ ,  driving  measurable  growth  in  ROI  and  user  \nengagement.\n ●  Contributed  to  investment  strategy  and  community  feedback  loops  to  improve  \nsatisfaction.\n \nTechnical  Product  Manager  ·  Mar  2022  –  Apr  2024  \n●  Introduced  a  customer  feedback  loop  that  improved  user  satisfaction  by  20%  and  \ndecreased\n \nnegative\n \nreviews.\n ●  Built  and  launched  an  admin  dashboard  managing  activity  across  5  blockchain  \nnetworks\n,\n \nreducing\n \nchurn\n \nby\n \n91%\n \nin\n \n6\n \nmonths.\n ●  Delivered  strategic  direction  and  feature  development  across  6+  major  product  lines .  Product  Manager  ·  Oct  2021  –  Feb  2022  \n●  Managed  a  10+  person  team  that  launched  products  generating  $1M  in  revenue  within  \n4\n \nmonths.\n ●  Launched  a  mobile-responsive  dApp,  increasing  engagement  by  50%  and  DAU  by  25% .  ●  Led  collaboration  among  24+  team  members  to  drive  35%  user  base  growth  and  67%  \nincrease\n \nin\n \nprofitability\n.\n \n  \nLuxor  –  Lagos  (Contract )  \nAI  Product  Consultant  .  Feb  2024  –  May  2024  \n●  Designed  and  developed  an  AI-powered  luxury  authentication  system  utilizin ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "As of now, I do not hold a patent. My focus has primarily been on product management and development, where my strengths lie in driving product strategy and execution. If you have inquiries about my work or contributions in product development, I'd be happy to share more!"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='This is a good response. It is professional and acknowledges that they do not hold a patent, before pivoting to talk about their strengths.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The response is not acceptable because the agent is speaking in gibberish. The agent should respond that they do not have any patents.
# Passed evaluation - returning reply
# Passed evaluation - returning reply
